# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
x = [1, 2, 3]
x?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def my_func(a, b):
    """it is function for sum of 2 numbers"""
    return a + b

my_func??
# Out:
# Signature: my_func(a, b)
# Source:
# def my_func(a, b):
#     """it is function for sum of 2 numbers"""
#     return a + b
# File:      c:\users\administrator\appdata\local\temp\ipykernel_7244\3225232559.py
# Type:      function

# %%
import numpy as np
np         

my_var = 10
my_func
# Out:
# <function __main__.my_func(a, b)>

# %%
# %timeit sum(range(1000))
# Out:
# 6.87 μs ± 112 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
total = 0
for i in range(1000):
    total += i
# Out:
# 23.5 μs ± 310 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %time sum(range(1000000))
# Out:
# CPU times: total: 31.2 ms
# Wall time: 24 ms
# 499999500000

# %%
x = 10
y = [1, 2, 3]
z = "hello"

# %who
# %whos
# Out:
# my_func	 my_var	 np	 x	 y	 z
# Variable   Type        Data/Info
# --------------------------------
# my_func    function    <function my_func at 0x000001E09CAF5080>
# my_var     int         10
# np         module      <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# x          int         10
# y          list        n=3
# z          str         hello

# %%
# !dir
# Out:
#  Volume in drive F is Study
#  Volume Serial Number is 104A-0893
#
#  Directory of f:\IT\IT practice\AI-styding\Python_Data_Science_2nd\Part_I_Jupyter_Beyond_Normal_Python
#
# 05/27/2026  09:22 AM    <DIR>          .
# 05/27/2026  09:02 AM    <DIR>          ..
# 05/27/2026  09:27 AM             4,015 tutorial.ipynb
#                1 File(s)          4,015 bytes
#                2 Dir(s)  88,413,487,104 bytes free

# %%
# !echo "hello"
# Out:
# "hello"

# %%
def buggy_func(x):
    return x / 0

# %%
# %debug
# Out:
# > c:\users\administrator\appdata\local\temp\ipykernel_7244\1106661705.py(2)buggy_func()

# %%
def my_function(n):
    result = []
    for i in range(1000):
        result.append(i ** 2)
    return sum(result)

# %prun my_function(1000)
# Out:
#          1005 function calls in 0.001 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.001    0.001 2647023790.py:1(my_function)
#      1000    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
